# %% [markdown]
# # Episode 2: Hard Times at the Huskin' Bee

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../data/cleaned_over_the_garden_wall_dialogue.csv')

# Filter for just Episode 2
episode_2_df = df[df['episode'] == "Episode 2: Hard Times at the Huskin' Bee"].copy()

# %%
# Print all dialogue from episode 2
print("\nEpisode 2 Dialogue:")
print("-" * 50)
for _, row in episode_2_df.iterrows():
    print(f"{row['char_name']}: {row['line']}")
    print("-" * 50)
# Out:
# Episode 2 Dialogue:
# --------------------------------------------------
# Wirt: It's almost morning. We should've found a town by now.  This—is the way the Woodsman told us to go, right?
# --------------------------------------------------
# Greg: Have you listened to anything I've been saying? For the last couple of hours I've been saying—
# --------------------------------------------------
# Wirt: Well, that settles it——I'm gonna walk up ten feet ahead of you.
# --------------------------------------------------
# Beatrice: Help!
# --------------------------------------------------
# Greg: Huh?
# --------------------------------------------------
# Beatrice: I'm stuck!
# --------------------------------------------------
# Greg: I hear something!
# --------------------------------------------------
# Wirt: It's probably nothing. Hey, look.  Pottsfield, one mile.  A town! Let's go this way!
# --------------------------------------------------
# Greg: Alright. Let's go this way.
# ...
